# %% [markdown]
# # Libraries

# %%
import numpy as np 
import pandas as pd 
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load Data

# %%
math_scores = pd.read_csv('raw student data/student-mat.csv')

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\omarch\Desktop\Rami\projects\ML projects\Smart Student Performance Predictor
